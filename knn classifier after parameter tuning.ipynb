# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/text-classification-data/training.csv
# /kaggle/input/text-classification-data/test.csv

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('/kaggle/input/text-classification-data/training.csv')
df2 = pd.read_csv('/kaggle/input/text-classification-data/test.csv')
df1.head()
# Out:
#    article_number                                      article_words  \
# 0               1  open,absent,cent,cent,cent,stock,inflow,rate,k...
# 1               2  morn,stead,end,end,day,day,day,patch,patch,pat...
# 2               3  socc,socc,world,world,recent,law,fifa,fifa,fif...
# 3               4  open,forint,forint,forint,forint,cent,cent,ste...
# 4               5  morn,complet,weekend,minut,minut,minut,arrow,d...
#
#            topic
# 0  FOREX MARKETS
# 1  MONEY MARKETS
# 2         SPORTS
# 3  FOREX MARKETS
# 4     IRRELEVANT

# %%
import matplotlib.pyplot as plt
df.groupby('topic').article_words.count().plot.bar(ylim=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0a3174f0e8e5> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 df.groupby('topic').article_words.count().plot.bar(ylim=0)
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
category_codes = {
    'ARTS CULTURE ENTERTAINMENT': 0,
    'BIOGRAPHIES PERSONALITIES PEOPLE': 1,
    'DEFENCE': 2,
    'DOMESTIC MARKETS': 3,
    'FOREX MARKETS': 4,
    'HEALTH': 5,
    'MONEY MARKETS': 6,
    'SCIENCE AND TECHNOLOGY': 7,
    'SHARE LISTINGS': 8,
    'SPORTS': 9,
    'IRRELEVANT': 10
}

# %%
df1 = df1.replace(category_codes)
df2 = df2.replace(category_codes)

# %%
data = pd.concat([df1['article_words'],df2['article_words']])

# %%
len(data)
# Out:
# 10000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
# Create bag of words
count = TfidfVectorizer()
bag_of_words = count.fit(data)

# %%
x_train = df1['article_words']
y_train = df1['topic'].to_list()
x_test = df2['article_words']
y_test = df2['topic'].to_list()

# %%
#Transforming the testing and training
x_train = bag_of_words.transform(x_train)
x_test = bag_of_words.transform(x_test)

# %%
#TFID vectoriser
#print(count.get_feature_names())
# Out:
# ['_____', '______', '_______', '____________', '_bret', 'a1', 'a1b1', 'a2', 'a3', 'a300', 'a300b4', 'a320', 'a330', 'a340', 'a4', 'a5', 'a6', 'a7', 'a78', 'a7e', 'aa', 'aa1', 'aa2', 'aa3', 'aaa', 'aacount', 'aad', 'aadj', 'aag', 'aah', 'aahp', 'aaii', 'aair', 'aalborg', 'aalst', 'aalton', 'aaltonaa', 'aama', 'aamir', 'aamodt', 'aandewiel', 'aap', 'aapc', 'aapt', 'aaqib', 'aaquib', 'aardolie', 'aardvark', 'aargau', 'aarhus', 'aaron', 'aarp', 'aarts', 'aasgard', 'aash', 'aato', 'ab', 'aba', 'abab', 'ababia', 'abac', 'abach', 'aback', 'abacus', 'abad', 'abandon', 'abar', 'abat', 'abattoir', 'abax', 'abay', 'abaz', 'abb', 'abba', 'abbasbeyl', 'abbasov', 'abbey', 'abbot', 'abbrev', 'abc', 'abc1', 'abcd', 'abciximab', 'abcl', 'abcp', 'abdal', 'abdel', 'abdelatif', 'abdelkad', 'abdelwahhab', 'abderdeen', 'abderrahim', 'abderrahm', 'abdicat', 'abdom', 'abdomin', 'abdoujaparov', 'abduc', 'abdul', 'abdulah', 'abdull', 'abdullah', 'abdullatif', 'abdullayev', 'abdulmejid', 'abdulmuhsin', 'abdur', 'abdus', 'abe', 'abed', 'abedin', 'abeg', 'abeijon', 'abel', 'abelard', 'abenign', 'aber', 'aberdeen', 'abereen', 'aberlich', 'aberneth', 'aberrat', 'aberystwyth', 'abet', 'abey', 'abhor', 'abi', 'abid', 'abidj', 'abigail', 'abil', 'abiol', 'abioudun', 'abitib', 'abiyev', 'abject', 'abkhaz', 'abkr', 'abl', 'ablaz', 'ablet', 'abloy', 'ably', 'abm', 'abn', 'abnd', 'abnorm', 'aboard', 'abod', 'abol', 'abolhass', 'abolut', 'abomin', 'abood', 'aborigin', 'abort', 'abot', 'abou', 'abound', 'abousay', 'abr', 'abra', 'abraham', 'abrahamson', 'abram', 'abramson', 'abras', 'abreast', 'abrie', 'abril', 'abroad', 'abrupt', 'abruzz', 'abs', 'absa', 'abscess', 'absens', 'absent', 'absentee', 'absolf', 'absolut', 'absorb', 'abstain', 'abstent', 'abstin', 'abstract', 'absurd', 'absytent', 'abtrust', 'abu', 'abuj', 'abul', 'abund', 'abus', 'abusiv', 'abut', 'abv', 'abvp', 'abysm', 'abyss', 'ac', 'acacia', 'academ', 'acadmem', 'acapulc', 'acar', 'acb', 'acc', 'accc', 'acccept', 'acccord', 'acccount', 'acced', 'accel', 'accelar', 'accent', 'accentu', 'accept', 'access', 'accessibl', 'acci', 'accid', 'acciv', 'accl', 'acclaim', 'acclam', 'acclimat', 'acco', 'accoceber', 'accol', 'accommod', 'accomod', 'accompan', 'accompl', 'accomplic', 'accopunt', 'accor', 'accord', 'account', 'accout', 'accredit', 'accret', 'accru', 'accrual', 'acct', 'accumul', 'accur', 'accurat', 'accus', 'accusat', 'accuss', 'accust', 'accustom', 'ace', 'aced', 'aceh', 'acei', 'acer', 'acerer', 'acero', 'aceved', 'acf', 'acfa', 'ach', 'achary', 'achief', 'achill', 'aci', 'acid', 'acindar', 'acitiv', 'ack', 'ackerm', 'acklin', 'acknowledg', 'acm', 'acmi', 'acolyt', 'aconcagua', 'acorn', 'acost', 'acount', 'acoust', 'acp', 'acpc', 'acquaint', 'acquiesc', 'acquiet', 'acquir', 'acquisiton', 'acquist', 'acquit', 'acqus', 'acr', 'acre', 'acrf', 'acri', 'acrid', 'acril', 'acrimon', 'acro', 'acrobat', 'acronym', 'acrux', 'acryl', 'acsp', 'act', 'actel', 'action', 'activ', 'activat', 'activcard', 'activex', 'activid', 'activit', 'acton', 'actress', 'actu', 'actual', 'actuar', 'acun', 'acut', 'acutek', 'acy', 'ad', 'adach', 'adailton', 'adair', 'adam', 'adamnet', 'adamson', 'adan', 'adapt', 'adaptat', 'adar', 'adcock', 'add', 'addendum', 'addi', 'addict', 'addimokrat', 'addion', 'addison', 'addonisio', 'addoum', 'address', 'adebay', 'adec', 'adecc', 'adeday', 'adef', 'adel', 'adelaid', 'adelek', 'adelm', 'adelph', 'ademol', 'aden', 'adenau', 'adenom', 'adenovirus', 'adequ', 'adequat', 'ader', 'adevarul', 'adha', 'adhes', 'adhigun', 'adhoc', 'adi', 'adia', 'adid', 'adil', 'adirondack', 'adit', 'adj', 'adjac', 'adject', 'adjoin', 'adjopt', 'adjourn', 'adjudg', 'adjust', 'adjuv', 'adl', 'adm', 'admin', 'administ', 'adminstor', 'adminstr', 'admir', 'admiralt', 'admirat', 'admissibl', 'admit', 'admon', 'adn', 'adnan', 'adnoc', 'adnrea', 'adob', 'adol', 'adolf', 'adolfson', 'adolph', 'adon', 'adopt', 'ador', 'adorn', 'adp', 'adr', 'adress', 'adri', 'adriamycin', 'adrian', 'adriat', 'adriatic', 'adrien', 'adrif ...

# %%
#X2 = count.fit_transform(x_train) 
#print(X2.toarray())

# %%
from sklearn.neighbors import KNeighborsClassifier
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import ShuffleSplit

# %%
#Cross-Validation for Hyperparameter tuning
knn =KNeighborsClassifier()
model = knn.fit(x_train,y_train)

# %%
y_predict = model.predict(x_test)

# %%
train_accuracy_score = accuracy_score(y_train,model.predict(x_train))
test_accuracy_score = accuracy_score(y_test,model.predict(x_test))
print(f'Accuracy Score for training data : {train_accuracy_score}.\n')
print(f'Accuracy Score for testing data : {test_accuracy_score}.\n')
# Out:
# Accuracy Score for training data : 0.8090526315789474.
#
# Accuracy Score for testing data : 0.702.

# %%
#Classification Report and Metrics Report
print(precision_score(y_test, y_predict,average = 'micro'))
print(recall_score(y_test, y_predict,average='micro'))
print(f1_score(y_test, y_predict, average='micro'))
print(f1_score(y_test, y_predict, average='macro'))
print(classification_report(y_test, y_predict))
# Out:
# 0.702
# 0.702
# 0.702
# 0.5007780538444128
#               precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33         3
#            1       0.60      0.20      0.30        15
#            2       0.58      0.54      0.56        13
#            3       0.33      0.50      0.40         2
#            4       0.33      0.46      0.38        48
#            5       0.62      0.71      0.67        14
#            6       0.45      0.61      0.52        69
#            7       0.00      0.00      0.00         3
#            8       1.00      0.43      0.60         7
#            9       0.93      0.92      0.92        60
#           10       0.87      0.78      0.82       266
#
#     accuracy                           0.70       500
#    macro avg       0.55      0.50      0.50       500
# weighted avg       0.74      0.70      0.71       500

# %%
#calculating auc roc score
fp_rate

# %%
#paramter tuning using grid search
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [3,5,11,19], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']}
grid = GridSearchCV(KNeighborsClassifier(),param_grid,verbose=1, cv=3, n_jobs = -1)
grid.fit(x_train,y_train)
print(grid.best_estimator_)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=11, p=2,
#                      weights='distance')
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:  3.8min finished

# %%
#After corss validation
knn_1 = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
                     metric_params=None, n_jobs=None, n_neighbors=11, p=2,
                     weights='distance')
model_1 = knn_1.fit(x_train,y_train)

# %%
y_predict_1 = model_1.predict(x_test)

# %%
#Classification Report and Metrics Report
print(precision_score(y_test, y_predict_1,average = 'micro'))
print(recall_score(y_test, y_predict_1,average='micro'))
print(f1_score(y_test, y_predict_1, average='micro'))
print(f1_score(y_test, y_predict_1, average='macro'))
print(classification_report(y_test, y_predict_1))
# Out:
# 0.708
# 0.708
# 0.708
# 0.4197309732031011
#               precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33         3
#            1       0.00      0.00      0.00        15
#            2       0.80      0.62      0.70        13
#            3       0.00      0.00      0.00         2
#            4       0.37      0.40      0.38        48
#            5       0.60      0.43      0.50        14
#            6       0.44      0.68      0.54        69
#            7       0.00      0.00      0.00         3
#            8       0.67      0.29      0.40         7
#            9       0.92      0.97      0.94        60
#           10       0.85      0.80      0.82       266
#
#     accuracy                           0.71       500
#    macro avg       0.45      0.41      0.42       500
# weighted avg       0.71      0.71      0.70       500
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#from sklearn.feature_extraction.text import CountVectorizer
#count_1 = CountVectorizer()
#bag_of_words_1 = count_1.fit(data)
